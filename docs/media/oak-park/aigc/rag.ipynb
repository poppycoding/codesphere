# %% [markdown]
# # 准备环境
# 需要下载相关依赖包，并设置API调用的环境变量。
#
# 不同大模型平台提供的环境变量不同，这里以百度千帆大模型平台的设置为例进行展示。
# 千帆平台上获取AK、SK的方法见文档 https://cloud.baidu.com/doc/Reference/s/9jwvz2egb

# %%
# !pip list | grep langchain
# !pip list | grep qianfan
# !pip list | grep faiss-cpu
# Out:
# langchain                 0.2.1
# langchain-community       0.2.1
# langchain-core            0.2.3
# langchain-text-splitters  0.2.0
# qianfan                   0.3.14
# faiss-cpu                 1.8.0

# %%
import os

os.environ['QIANFAN_AK'] = "xxx"
os.environ['QIANFAN_SK'] = "xxx"

# %% [markdown]
# # langchain的基本使用：调用大模型
# LangChain（https://www.langchain.com/ ）是一个由语言模型LLM驱动的应用程序框架，它允许用户围绕大型语言模型快速构建应用程序。LangChain本身并不开发LLM，它的核心理念是为各种LLM提供通用的接口，降低开发者的学习成本，方便开发者快速地开发复杂的LLMs应用。它提供了一套工具、组件和接口，可简化创建由大型语言模型（LLM）和聊天模型提供支持的应用程序的过程。
#
# 本次课程将介绍如何用langchain来开发一个检索增强生成（RAG）应用。
#
# 首先看看langchain的基本使用，下面是用langchain来调用文心一言3.5 API的例子。

# %%
from langchain.chat_models import QianfanChatEndpoint

llm = QianfanChatEndpoint(model="ERNIE-3.5-8K")

# %%
llm.invoke("写一首学习RAG的诗")
# Out:
# AIMessage(content='学习RAG\n\nRAG语言妙无穷，逻辑编程显神通。\n数据结构精心构，函数方法巧运用。\n代码运行似流水，算法优化如飞鸿。\n勤奋学习终有成，编程之路任驰骋。', additional_kwargs={'finish_reason': 'normal', 'request_id': 'as-6twukzhetp', 'object': 'chat.completion', 'search_info': [], 'function_call': {}, 'tool_calls': [{'type': 'function', 'function': {}}]}, response_metadata={'token_usage': {'prompt_tokens': 6, 'completion_tokens': 52, 'total_tokens': 58}, 'model_name': 'ERNIE-3.5-8K', 'finish_reason': 'normal', 'id': 'as-6twukzhetp', 'object': 'chat.completion', 'created': 1717344423, 'result': '学习RAG\n\nRAG语言妙无穷，逻辑编程显神通。\n数据结构精心构，函数方法巧运用。\n代码运行似流水，算法优化如飞鸿。\n勤奋学习终有成，编程之路任驰骋。', 'is_truncated': False, 'need_clear_history': False, 'usage': {'prompt_tokens': 6, 'completion_tokens': 52, 'total_tokens': 58}}, id='run-9fc4027e-ecad-4e24-ad56-ebadd308e8a2-0')

# %% [markdown]
# 可以在输入前加上一个问题模版（prompt template），让大模型回答问题时遵循模版上的要求。

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "你是一个擅长写七言绝句的诗人，而且在诗中善于融入现代社会的工作学习方式。"),
    ("user", "{input}")
])

# %% [markdown]
# 然后可以用langchain重载过的运算符 | 将问题模版和llm串联起来，组成一个调用链 chain。

# %%
chain = prompt | llm

# %%
chain.invoke({"input": "写一首学习RAG的诗"})
# Out:
# AIMessage(content='学习RAG真奇妙，\n代码编织逻辑高。\n智能模型显神通，\n未来世界任逍遥。', additional_kwargs={'finish_reason': 'normal', 'request_id': 'as-fgg91yaeqt', 'object': 'chat.completion', 'search_info': [], 'function_call': {}, 'tool_calls': [{'type': 'function', 'function': {}}]}, response_metadata={'token_usage': {'prompt_tokens': 29, 'completion_tokens': 24, 'total_tokens': 53}, 'model_name': 'ERNIE-3.5-8K', 'finish_reason': 'normal', 'id': 'as-fgg91yaeqt', 'object': 'chat.completion', 'created': 1717344553, 'result': '学习RAG真奇妙，\n代码编织逻辑高。\n智能模型显神通，\n未来世界任逍遥。', 'is_truncated': False, 'need_clear_history': False, 'usage': {'prompt_tokens': 29, 'completion_tokens': 24, 'total_tokens': 53}}, id='run-dc63aeb1-8ee4-4035-80ae-0e3a9c9eda5a-0')

# %% [markdown]
# # 检索增强生成（RAG）方案
# 总体上分为准备阶段和调用阶段。
#
# ## 准备阶段
# 1. 准备待检索的文档，最好是清洗之后的纯文本格式
# 2. 将文档切分成文档片段
# 3. 选择向量模型和向量库，将文档片段通过向量模型转换成向量，然后存入向量库
#
# ## 调用阶段
# 4. 编写prompt将用户问题和检索到的文档片段拼接到一起
# 5. 将向量检索过程和模型调用串联起来

# %% [markdown]
# ## 1 准备待检索的文档
# 我们以千帆平台上的预置服务收费文档为例进行后续的演示，这个文档可以见链接 https://cloud.baidu.com/doc/WENXINWORKSHOP/s/hlrk4akp7 。
# 我们把这个文档复制成txt文件，然后用langchain的TextLoader进行加载。

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("data/招商银行介绍.txt", encoding='utf8')
loader.load()

docs = loader.load()

# %%
docs
# Out:
# [Document(page_content='招商银行（China Merchants Bank）1987年成立于深圳蛇口，资产总额110285.00亿元， [90]是中国境内第一家完全由企业法人持股的股份制商业银行，也是国家从体制外推动银行业改革的第一家试点银行。 [1-3] [74]\n自2012年首次入围《财富》世界500强以来，已连续7年入围，2018年《财富》世界500强居213位。 [4-5]2019年6月26日，招商银行等8家银行首批上线运行企业信息联网核查系统。 [6]2019年7月，发布2019《财富》世界500强位列188位。 [7]2019年11月，“一带一路”中国企业100强榜单排名第85位。 [8]2019年12月，招商银行入选2019中国品牌强国盛典榜样100品牌。 [9]2019年12月18日，人民日报“中国品牌发展指数”100榜单排名第31位。 [10]2020年1月13日，入选2020胡润至尚优品获奖名单。2020年3月，入选2020年全球品牌价值500强第74位。 [11]2021年5月，位列“2021福布斯全球企业2000强”第22位。 [53]\nhttp://www.cmbchina.com/\n招商银行总行设在中国广东省深圳市福田区，2002年4月9日，招商银行A股在上海证券交易所挂牌上市。2006年9月8日，招商银行开始在香港公开招股，发行约22亿股H股，集资200亿港元，并在9月22日于港交所上市。资本净额超过2900亿、资产总额超过4.4万亿。 [3] [13-14]截至2017年上半年，招商银行境内外分支机构逾1800家，在中国大陆的130余个城市设立了服务网点，拥有5家境外分行和3家境外代表处，员工7万余人。此外，招商银行还在境内全资拥有招银金融租赁有限公司，控股招商基金管理有限公司，持有招商信诺人寿保险有限公司50%股权、招联消费金融公司50%股权；在香港全资控股永隆银行有限公司和招银国际金融控股有限公司。 [3]\n招商银行发展目标是成为中国领先的零售银行。1995年7月推出银行卡一卡通，1999年9月启动中国首家网上银行一网通，成为众多企业和电子商务网站广泛使用网上支付工具，在一定程度上促进了中国电子商务的发展。 [15-16]2015年4月2日，招商局集团有限公司筹划重大事项，为保证公平信息披露，维护投资者利益，避免造成公司股价异常波动，经公司申请，公司股票自2015年4月3日开市起停牌。2016年8月，招商银行在"2016中国企业500强"中排名第39位。 [17]\n国内最大私人银行换帅 赵悦接任招行私行部总经理 原总经理 [52]转投外资行。\n1987年，4月8日招行在深圳蛇口举行开业典礼，中国第一家由企业创办的银行自此诞生，王世桢任第一任行长 [18]。\n1988年，走出蛇口，开设了第一个分支机构——罗湖营业部。\n1989年，第一次增资扩股；同年成为第一家离岸业务试点银行。 [19-20]\n2015年4月3日，招商局集团有限公司（以下简称“招商局集团”）旗下的招商银行股份有限公司（招商银行，600036.SH；03968.HK）和招商局地产控股股份有限公司（招商地产，000024）同时发布停牌通告。\n招商银行北京分行风光(5张)\n2015年10月15日，招商银行在深圳推出了ATM“刷脸取款”业务，客户无需插入实体银行卡即可完成取款，每日限额取现3000元。 [21]客户如需取款，首先在ATM屏幕首页点击选择“刷脸取款”功能，系统将自动抓拍现场照片，在后台与银行的可信照片源进行比对，验证通过后，客户输入手机号码进一步确认身份，接着输入取款金额、密码，最后拿取现金，整个过程无需插入实体银行卡片。 [22]\n2017年2月，Brand Finance发布2017年度全球500强品牌榜单，招商银行排名第91。\n2018年7月19日，2018年《财富》世界500强排行榜发布，招商银行位列213位。 [23]\n2018年9月20日，招商银行在中国互金协会旗下的全国互联网金融登记披露服务平台上发布了的声明书，表示已通过个体网络借贷资金存管系统测评（P2P网贷机构存管银行“白名单”。）。 [24]\n2018年10月11日，福布斯发布2018年全球最佳雇主榜单，招商银行位列第160位。 [25]\n2018年11月1日，招商银行深圳分行在为客户办理贵金属购买业务后，通过系统直联深圳市税务局区块链平台，开出了首张区块链电子发票，首批通过系统直接接入深圳市区块链电子发票平台，也成为全国首个区块链电子发票的试点银行。 [26]\n招商银行（长沙）(5张)\n2020年1月25日，大年正月初一，在全国上下防控新型冠状病毒肺炎疫情的关键时刻，招商银行决定通过武汉市慈善总会向武汉市捐款2亿元，全力支援武汉抗击疫情。在武汉市新型肺炎防控指挥部发布接受社会捐赠的公告后，招行第一时间响应号召，特事特办启动相关流程，在短时间内完成内部审批，捐出2亿元驰援武汉。据悉，捐款的款项将由武汉市新型肺炎防控指挥部作为疫情防控专款使用。 [27]\n2021年10月，被评估认定为国内系统重要性银行； [54]12月1日，招商银行官方宣布苏炳添出任全球品牌代言人。 [57]\n2022年11月18日，入选银保监会发布的首批开办个人养老金业务的机构名单。 [69]\n2023年5月31日，招商银行召开董事会会议，提名朱江涛为公司第十二届董事会执行董事候选人，并提交股东大会审议。 [75]\n2023年6月12日，招商银行宣布下调人民币活期、定期存款利率。 [77]\n2023年9月，被认定为系统重要性银行。 [81]\n2023年12月22日，招商银行1年、2年、3年、5年期整存整取定期存款挂牌利率为1.45%、1.65%、1.95%、2%。在此之前则分别为1.55%、1.85%、2.2%、2.25%。与大行相同，1年定期存款利率下调10个基点、2年定期存款利率下调20个基点、3年定期存款普遍下调25个基点，5年定期存款利率普遍下调25个基点。 [86-87]\n2024年1月19日，招商银行发布业绩快报，2023年净利润1466亿元，同比增长6.22%。 [89]\n2024年1月，招行总行调整零售业务条线组织架构，新设零售客群部，并由财富平台部总经理厉明东兼任总经理。同时，还调整了其他零售核心业务中层负责人。 [91]\n2024年，招商银行在港交所发布公告称，审议通过了《关于设立迪拜分行的议案》，公司在阿联酋的迪拜国际金融中心（DIFC）设立分行，向迪拜金融服务管理局（DFSA）申请颁牌，拨付营运资金美元5,000万元，机构名称为“招商银行股份有限公司迪拜金融中心分行”，简称“招商银行迪拜分行”，最终以国家金融监督管理总局审批文件为准。撤销公司美国代表处，相应职责由公司纽约分行承接。正式撤销以国家金融监督管理总局审批文件为准。 [93]\n2024年4月9日，从招商银行客户经理处获悉，目前该行已不再新发三年期、五年期大额存单产品额度。 [94]\n薪福通：薪福通是提供“普惠的企业数字化服务”，即以薪福通为载体的“一站式企业数字服务通用平台”服务。薪福通是招商银行旗下的SaaS产品，依托招商银行行业的金融科技力量和优质服务能力，为中国企业提供普惠的企业数字化服务。 [65]\n借记卡：分为一卡通和金葵花卡，功能集定活期、多储种、多币种、多功能于一体。\n信用卡：采用芯片+磁条的形式的信用卡，具有透支，积分等信用卡的一切功能。\n金葵花理财：面向个人高端客户提供的综合理财服务体系，涵盖负债、资产、中间业务及理财顾问。\n招商信诺 [51]：招商信诺资管获批筹建 将成第四家外资保险资管公司\n股东和股东会：招商局集团有限公司通过旗下的招商局轮船有限公司、深圳市招融投资控股有限公司、深圳市晏清投资发展有限公司、深圳市楚源投资发展有限公司、China Merchants Union (BVI) Limited、Best Winner Investment Limited和招商局实业发展（深圳）有限公司合并间接持有本公司29.97%的股份，不存在出质本公司股份的情况。其中，招商局轮船有限公司直接持有本公司13.04%的股份，是本公司第一大股东，注册资本70亿。 [56]\n董事和董事会：下设战略委员会、审计委员会、关联交易控制委员会、风险管理委员会、提名委员会、薪酬与考核委员会等6个专门委员会，每个委员会有5名成员\n监事和监事会：监事会有成员9名，其中外部监事2名、股东监事4名、职工监事3名。制定监事会议事规则，明确监事会的议事方式和表决程序，以确保监事会的有效监督。\n2023年\n2023年5月10日，“2023百大年度品牌榜”正式公布，招商银行位居总榜第10位。 [72]\n2023年6月，入选福布斯发布的2023年福布斯全球企业2000强榜单，位列第26名。 [76]\n2022年\n2022年5月，招商银行位列“2022福布斯全球企业2000强”第24位。\n2022年，入选英国《银行家》杂志公布的“2022年全球银行1000强”榜单，位列第11位。 [66]\n2022年9月9日，人民银行、银保监会发布2022年度我国系统重要性银行名单，该银行在列。 [67]\n2021年\n2021年5月，招商银行位列“2021福布斯全球企业2000强”第22位。 [53]\n2021年9月23日，招商银行位列2021年《亚洲品牌500强》排行榜第157位。 [55]\n2021年，入选钛媒体 2021 EDGE A ...

# %% [markdown]
# ## 2 将长文档切成小的文本片段
# 一般参考的文档都比较长，我们需要将他们切分成小的文本片段，然后将这些片段转换成向量，存入向量库留待以后检索用。文本片段是做检索的最小单位。
#
# RecursiveCharacterTextSplitter可以做切分文档的工作，其中chunk_size表示切分片段的长度，chunk_overlap表示不同片段之间重叠的长度，separators表示切分时优先使用哪些符号作为片段之间的分割。

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=0, separators=["\n\n", "\n", "。", "]", " ", ""])
documents = text_splitter.split_documents(docs)

# %%
print(len(documents))
documents
# Out:
# 54
# [Document(page_content='招商银行（China Merchants Bank）1987年成立于深圳蛇口，资产总额110285.00亿元， [90]是中国境内第一家完全由企业法人持股的股份制商业银行，也是国家从体制外推动银行业改革的第一家试点银行。 [1-3] [74]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='自2012年首次入围《财富》世界500强以来，已连续7年入围，2018年《财富》世界500强居213位。 [4-5]2019年6月26日，招商银行等8家银行首批上线运行企业信息联网核查系统。 [6]2019年7月，发布2019《财富》世界500强位列188位。 [7]2019年11月，“一带一路”中国企业100强榜单排名第85位', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='。 [8]2019年12月，招商银行入选2019中国品牌强国盛典榜样100品牌。 [9]2019年12月18日，人民日报“中国品牌发展指数”100榜单排名第31位。 [10]2020年1月13日，入选2020胡润至尚优品获奖名单。2020年3月，入选2020年全球品牌价值500强第74位。 [11]2021年5月，位列“2021福布斯全球企业2000强”第22位。 [53]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='http://www.cmbchina.com/', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='招商银行总行设在中国广东省深圳市福田区，2002年4月9日，招商银行A股在上海证券交易所挂牌上市。2006年9月8日，招商银行开始在香港公开招股，发行约22亿股H股，集资200亿港元，并在9月22日于港交所上市。资本净额超过2900亿、资产总额超过4.4万亿', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='。 [3] [13-14]截至2017年上半年，招商银行境内外分支机构逾1800家，在中国大陆的130余个城市设立了服务网点，拥有5家境外分行和3家境外代表处，员工7万余人。此外，招商银行还在境内全资拥有招银金融租赁有限公司，控股招商基金管理有限公司，持有招商信诺人寿保险有限公司50%股权、招联消费金融公司50%股权；在香港全资控股永隆银行有限公司和招银国际金融控股有限公司。 [3]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='招商银行发展目标是成为中国领先的零售银行。1995年7月推出银行卡一卡通，1999年9月启动中国首家网上银行一网通，成为众多企业和电子商务网站广泛使用网上支付工具，在一定程度上促进了中国电子商务的发展。 [15-16]2015年4月2日，招商局集团有限公司筹划重大事项，为保证公平信息披露，维护投资者利益，避免造成公司股价异常波动，经公司申请，公司股票自2015年4月3日开市起停牌', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='。2016年8月，招商银行在"2016中国企业500强"中排名第39位。 [17]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='国内最大私人银行换帅 赵悦接任招行私行部总经理 原总经理 [52]转投外资行。\n1987年，4月8日招行在深圳蛇口举行开业典礼，中国第一家由企业创办的银行自此诞生，王世桢任第一任行长 [18]。\n1988年，走出蛇口，开设了第一个分支机构——罗湖营业部。\n1989年，第一次增资扩股；同年成为第一家离岸业务试点银行。 [19-20]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2015年4月3日，招商局集团有限公司（以下简称“招商局集团”）旗下的招商银行股份有限公司（招商银行，600036.SH；03968.HK）和招商局地产控股股份有限公司（招商地产，000024）同时发布停牌通告。\n招商银行北京分行风光(5张)', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2015年10月15日，招商银行在深圳推出了ATM“刷脸取款”业务，客户无需插入实体银行卡即可完成取款，每日限额取现3000元。 [21]客户如需取款，首先在ATM屏幕首页点击选择“刷脸取款”功能，系统将自动抓拍现场照片，在后台与银行的可信照片源进行比对，验证通过后，客户输入手机号码进一步确认身份，接着输入取款金额、密码，最后拿取现金，整个过程无需插入实体银行卡片。 [22]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2017年2月，Brand Finance发布2017年度全球500强品牌榜单，招商银行排名第91。\n2018年7月19日，2018年《财富》世界500强排行榜发布，招商银行位列213位。 [23]\n2018年9月20日，招商银行在中国互金协会旗下的全国互联网金融登记披露服务平台上发布了的声明书，表示已通过个体网络借贷资金存管系统测评（P2P网贷机构存管银行“白名单”。）。 [24]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2018年10月11日，福布斯发布2018年全球最佳雇主榜单，招商银行位列第160位。 [25]\n2018年11月1日，招商银行深圳分行在为客户办理贵金属购买业务后，通过系统直联深圳市税务局区块链平台，开出了首张区块链电子发票，首批通过系统直接接入深圳市区块链电子发票平台，也成为全国首个区块链电子发票的试点银行。 [26]\n招商银行（长沙）(5张)', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2020年1月25日，大年正月初一，在全国上下防控新型冠状病毒肺炎疫情的关键时刻，招商银行决定通过武汉市慈善总会向武汉市捐款2亿元，全力支援武汉抗击疫情。在武汉市新型肺炎防控指挥部发布接受社会捐赠的公告后，招行第一时间响应号召，特事特办启动相关流程，在短时间内完成内部审批，捐出2亿元驰援武汉。据悉，捐款的款项将由武汉市新型肺炎防控指挥部作为疫情防控专款使用。 [27]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2021年10月，被评估认定为国内系统重要性银行； [54]12月1日，招商银行官方宣布苏炳添出任全球品牌代言人。 [57]\n2022年11月18日，入选银保监会发布的首批开办个人养老金业务的机构名单。 [69]\n2023年5月31日，招商银行召开董事会会议，提名朱江涛为公司第十二届董事会执行董事候选人，并提交股东大会审议。 [75]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2023年6月12日，招商银行宣布下调人民币活期、定期存款利率。 [77]\n2023年9月，被认定为系统重要性银行。 [81]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2023年12月22日，招商银行1年、2年、3年、5年期整存整取定期存款挂牌利率为1.45%、1.65%、1.95%、2%。在此之前则分别为1.55%、1.85%、2.2%、2.25%。与大行相同，1年定期存款利率下调10个基点、2年定期存款利率下调20个基点、3年定期存款普遍下调25个基点，5年定期存款利率普遍下调25个基点。 [86-87]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2024年1月19日，招商银行发布业绩快报，2023年净利润1466亿元，同比增长6.22%。 [89]\n2024年1月，招行总行调整零售业务条线组织架构，新设零售客群部，并由财富平台部总经理厉明东兼任总经理。同时，还调整了其他零售核心业务中层负责人。 [91]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2024年，招商银行在港交所发布公告称，审议通过了《关于设立迪拜分行的议案》，公司在阿联酋的迪拜国际金融中心（DIFC）设立分行，向迪拜金融服务管理局（DFSA）申请颁牌，拨付营运资金美元5,000万元，机构名称为“招商银行股份有限公司迪拜金融中心分行”，简称“招商银行迪拜分行”，最终以国家金融监督管理总局审批文件为准。撤销公司美国代表处，相应职责由公司纽约分行承接', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='。正式撤销以国家金融监督管理总局审批文件为准。 [93]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2024年4月9日，从招商银行客户经理处获悉，目前该行已不再新发三年期、五年期大额存单产品额度。 [94]\n薪福通：薪福通是提供“普惠的企业数字化服务”，即以薪福通为载体的“一站式企业数字服务通用平台”服务。薪福通是招商银行旗下的SaaS产品，依托招商银行行业的金融科技力量和优质服务能力，为中国企业提供普惠的企业数字化服务。 [65]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='借记卡：分为一卡通和金葵花卡，功能集定活期、多储种、多币种、多功能于一体。\n信用卡：采用芯片+磁条的形式的信用卡，具有透支，积分等信用卡的一切功能。\n金葵花理财：面向个人高端客户提供的综合理财服务体系，涵盖负债、资产、中间业务及理财顾问。\n招商信诺 [51]：招商信诺资管获批筹建 将成第四家外资保险资管公司', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='股东和股东会：招商局集团有限公司通过旗下的招商局轮船有限公司、深圳市招融投资控股有限公司、深圳市晏清投资发展有限公司、深圳市楚源投资发展有限公司、China Merchants Union (BVI) Limited、Best Winner Investment Limited和招商局实业发展（深圳）有限公司合并间接持有本公司29.97%的股份，不存在出质本公司股份的情况', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='。其中，招商局轮船有限公司直接持有本公司13.04%的股份，是本公司第一大股东，注册资本70亿。 [56]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='董事和董事会：下设战略委员会、审计委员会、关联交易控制委员会、风险管理委员会、提名委员会、薪酬与考核委员会等6个专门委员会，每个委员会有5名成员\n监事和监事会：监事会有成员9名，其中外部监事2名、股东监事4名、职工监事3名。制定监事会议事规则，明确监事会的议事方式和表决程序，以确保监事会的有效监督。\n2023年', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2023年5月10日，“2023百大年度品牌榜”正式公布，招商银行位居总榜第10位。 [72]\n2023年6月，入选福布斯发布的2023年福布斯全球企业2000强榜单，位列第26名。 [76]\n2022年\n2022年5月，招商银行位列“2022福布斯全球企业2000强”第24位。\n2022年，入选英国《银行家》杂志公布的“2022年全球银行1000强”榜单，位列第11位。 [66]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2022年9月9日，人民银行、银保监会发布2022年度我国系统重要性银行名单，该银行在列。 [67]\n2021年\n2021年5月，招商银行位列“2021福布斯全球企业2000强”第22位。 [53]\n2021年9月23日，招商银行位列2021年《亚洲品牌500强》排行榜第157位。 [55]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2021年，入选钛媒体 2021 EDGE AWARDS 全球创新评选之 「EDGE AWARDS 年度ESG实力先锋企业」榜单。 [59]\n2020年\n2020年1月3日，招商银行在2019年上市公司市值500强中，排名第12。 [29]\n2020年1月，2020年全球最具价值500大品牌榜发布，招商银行排名第74位。 [30]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2020年2月，2020年度“全球银行品牌价值500强排行榜”发布，招商银行排名第9位。 [31]\n2020年3月9日，“2019年中国银行业100强榜单”发布，招商银行排名第6位。 [32]\n2020年5月10日，“2020中国品牌500强”排行榜发布，招商银行排名第22位。\n2020年5月12日，人民日报中国品牌发展研究院发布中国品牌发展指数之中国企业社会责任领先指数，排名第19。', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2020年5月13日，招商银行名列2020福布斯全球企业2000强榜第26位。 [33-34]\n2020年8月10日，招商银行（CHINA MERCHANTS BANK）名列2020年《财富》世界500强排行榜第189位。 [35]\n2019年\n2019年12月12日，《汇桔网·2019胡润品牌榜》发布，招商银行以1100亿元品牌价值排名第18，2019金融品牌价值全国排名第7。', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2019年12月18日，人民日报“中国品牌发展指数”100榜单排名第31位。 [10]\n2019年7月22日，招商银行以12179（百万美元）的利润，荣获2019年世界500强最赚钱的50家公司第38名。 [36]\n2018年\n2018年1月，胡润百富正式发布《2018至尚优品-中国千万富豪品牌倾向调查报告》，本公司信用卡连续14年蝉联胡润百富“最受千万富豪青睐的信用卡”大奖。 [37]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2018年2月，在《欧洲货币》杂志举办的2018年全球最佳私人银行和财富管理机构颁奖盛典中，第8次荣获“中国区最佳私人银行”大奖。 [38]\n2018年3月，在《亚洲银行家》杂志举办的“2018年零售金融服务国际颁奖典礼”中获评“亚太区最佳零售银行”； [39]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2018年6月，在中国《银行家》杂志举办的“2018中国金融创新奖”评选活动中，荣获“最佳金融创新奖” [40]，“招赢通”互联网服务平台获“十佳金融科技产品创新奖”。\n2018年7月，在英国《银行家》杂志2018年全球银行1000强排名中位列第20位，较上年提高3个位次。', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2018年7月，《财富》杂志中国500强榜单揭晓，位列第38位；在《财富》杂志发布的世界500强榜单中，连续7年入榜，名列第213名，较上年上升了3个位次。 [41-42]\n2018年10月，在《亚洲货币》杂志举办的“2018中国卓越公司与投资银行”奖项评选中，荣获“中国最佳金融机构融资及投行业务”奖项 [43]；', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2018年11月，在智联招聘举办的“2018年中国人力资本国际管理论坛暨中国年度最佳雇主颁奖典礼”活动中，荣获“2018中国年度最佳雇主”奖项。 [44]\n2018年11月，入选《财新》杂志社2018年度“财新数据·商道融绿ESG（环境、社会和公司治理）美好50指数成分股”。 [45]\n2017年', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2017年2月，荣获《欧洲货币》“中国区最佳私人银行”奖项。在此次中国区私人银行服务评比中，除荣获超高净值客户（即投资资产3,000万美元以上）、高净值客户（即投资资产500万至3,000万美元）和超级富裕客户（即投资资产100万至500万美元）服务的最佳私人银行外，还获得了资产管理、家族办公室、商业银行服务能力、投行业务服务能力及科技创新等多项中国区第一，包揽了所有细分领域的榜首。', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2017年7月，《银行家》公布2017年全球银行1000强排名，以559.4亿美元的一级资本规模位列全球第23位。', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2017年3月17日，由《亚洲银行家》(《The Asian Banker》)主办的“2017年度国际零售金融服务卓越大奖”评选结果揭晓，第8次荣获“中国最佳零售银行”，第13次荣获“中国最佳股份制零售银行”', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='。同年荣获《亚洲银行家》(《The Asian Banker》)颁发的“中国最佳股份制交易银行”“中国最佳股份制现金管理银行”“中国最佳托管银行”“中国最佳金融供应链管理项目”“中国最佳现金管理项目”和“中国最佳资金管理服务中心”六项奖项。 [46]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2017年6月15日，在中国《银行家》杂志社举办的“2017中国金融创新奖”评选中，荣获“最佳金融创新奖”。 [47]\n2017年9月，在中国《银行家》杂志主办的2017中国商业银行竞争力排名颁奖典礼中，荣获“全国性商业银行财务评价第一”“全国性商业银行核心竞争力评价第三”“最佳全国性商业银行”和“最佳财富管理银行”四项奖项。 [48-49]', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2021-12\tEDGE AWARDS 年度ESG实力先锋企业\t获奖\t[58]\n获奖时间\t奖项名称\t获奖结果\n2020\t2020胡润至尚优品\t获奖\n2019\t最佳股份制商业银行 [50]\t获奖\n2019\t最具投资价值银行 [50]\t获奖\n2019\t最佳手机银行 [50]\t获奖\n2014\t最具企业社会责任感公司奖\t获奖\n2014\t年度最佳财富管理银行\t获奖\n2014\t年度卓越私人银行服务\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2014\t最佳创新银行奖\t获奖\n2014\t最佳中资银行奖\t获奖\n2013\t深圳市金融创新奖\t获奖\n2013\t卓越手机银行奖\t获奖\n2013\t中国银行业星级服务机构\t获奖\n2013\t北亚最佳私人银行\t获奖\n2013\t年度广告主品牌奖\t获奖\n2012\t中国高端私人理财金鼎奖\t获奖\n2012\t年度十大品牌银行奖\t获奖\n2012\t品牌中国华谱奖\t获奖\n2012\t搜狐金融德胜奖年度企业\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2012\t最具创意筹款奖\t获奖\n2011\t中国区最佳债券承销银行\t获奖\n2011\t中国人才发展最佳企业奖\t获奖\n2011\t中国最佳托管专业银行\t获奖\n2011\t最佳品牌风险管理奖\t获奖\n2011\t中国儿童慈善奖\t获奖\n2010\t亚洲银行家潜力与领导力发展大奖\t获奖\n2010\t中国银行业世博金融服务组织奖\t获奖\n2010\t《金融时报》FT中国世界级品牌\t获奖\n2010\t亚洲最佳顾客满意度银行\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2010\t最具幸福感金融企业\t获奖\n2010\t最受青睐中国私人银行\t获奖\n2009\t欧元清算直通率大奖\t获奖\n2009\t中国最佳托管银行新星奖\t获奖\n2009\t中国绿色公司2008年度星级标杆企业\t获奖\n2009\t北京奥运银行服务奖\t获奖\n2009\t美元清算直通率大奖\t获奖\n2009\t香港最佳并购交易奖\t获奖\n2009\t中国新锐基金托管银行奖\t获奖\n2009\t中国最佳私人银行奖\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2009\t最佳雇主50强\t获奖\n2008\t30年影响深圳人生活的功勋品牌\t获奖\n2008\t年度最佳外币理财银行\t获奖\n2008\t最受赞赏的中国公司\t获奖\n2008\t最佳人民币理财银行\t获奖\n2008\t年度最佳效益银行\t获奖\n2007\t亚太客户服务至尊金奖\t获奖\n2007\t中国银行卡和支付业务成就奖\t获奖\n2007\t十佳电子商务物流创新企业\t获奖\n2007\t中国网上银行业务成就奖\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2007\t中国最佳物流银行\t获奖\n2007\t中国金融营销十佳奖\t获奖\n2007\t中国CFO最信赖的银行\t获奖\n2007\t最佳金融服务奖\t获奖\n2007\t中国品牌年度大奖\t获奖\n2007\t商业银行卓越绩效管理一等奖\t获奖\n2006\t最佳企业公众形象奖\t获奖\n2006\t深圳市金融创新奖\t获奖\n2006\t最具社会责任企业\t获奖\n2006\t最佳零售服务奖\t获奖\n2006\t中国创造奖\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2005\t亚洲最佳管理公司\t获奖\n2005\t深圳知名品牌\t获奖\n2005\t中国最具生命力企业100强\t获奖\n2005\t中国客户关怀标杆企业\t获奖\n2005\t中国呼叫中心服务质量管理十佳满意品牌\t获奖\n2005\t中国最佳企业公民行为大奖\t获奖\n2005\t十佳中国大陆卓越雇主品牌企业\t获奖\n2005\t中国上市公司综合竞争力20强\t获奖\n2005\t最具员工成长价值企业\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2005\t中国商业网站100强\t获奖\n2005\t中国生活方式最佳品牌\t获奖\n2005\t中国本土最佳现金管理银行\t获奖\n2005\t中国最具创新力公司\t获奖\n2005\t中国品牌建设年度十大案例\t获奖\n2005\t新浪网最信赖银行\t获奖\n2005\t中国企业文化优秀奖\t获奖\n2005\t中国最佳表现公司\t获奖\n2005\t深圳最具竞争力企业10强\t获奖\n2005\t大学生最佳雇主人气奖\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2005\t中国最佳CRM实施\t获奖\n2005\t中国企业网站100强\t获奖\n2004\t中国本土最佳贸易融资银行\t获奖\n2004\t中国企业文化建设十佳单位\t获奖\n2003\t中华人民共和国民政部爱心捐助奖\t获奖\n2003\t银行卡联网通用突出贡献奖\t获奖\n2003\t中国最佳电子金融应用企业\t获奖\n2003\t最具竞争优势百家企业\t获奖\n2003\t中国红十字博爱奖章\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='2003\t中国企业信息化500强\t获奖\n2002\t世界1000家大银行\t获奖\n2002\t最具有影响力企业\t获奖\n2002\t中国最受尊敬的企业\t获奖\n2000\t招商银行官网十大最受欢迎网站之一\t获奖\n2000\t世界25家最佳资本利润率银行\t获奖\n2000\t中国本土最佳商业银行\t获奖\n1999\t一网通为互联网10件大事之一\t获奖\n1999\t最受欢迎的中国银行卡第三位\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='1999\t招商银行官网中国十大优秀网站之一\t获奖\n1999\t亚洲最大100家银行第一位\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='招商银行LOGO招商银行字体为“爨宝子”体，是1987年由当时87岁的广东省书法家协会主席秦咢生老先生所题。秦咢生先生（1900年～1990年）于书兼擅数体，尤精究东晋名碑《爨宝子碑》，曾作《集爨论爨十绝》，所作“爨宝子”体，尤得其神理意趣，故时人美其名曰“秦宝子”。所以，只要略通书法的人，就会发现“招商银行”四字与《爨宝子碑》酷似逼肖', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='。秦咢生所题“招商银行”四字，深得《爨宝子碑》之神韵，但比其更加粗壮雄浑，四个字稚拙古朴，隶意浓厚，气质高古，极富个性，让人过目不忘。', metadata={'source': 'data/招商银行介绍.txt'}),
#  Document(page_content='招商银行的LOGO由深圳韩家英设计有限公司设计。', metadata={'source': 'data/招商银行介绍.txt'})]

# %% [markdown]
# ## 3.1 向量模型
# 将文档片段转换成向量需要向量模型，在千帆平台上同样提供了向量模型的调用服务，详见 https://cloud.baidu.com/doc/WENXINWORKSHOP/s/Nlks5zkzu#%E5%90%91%E9%87%8Fembeddings

# %%
from langchain.embeddings import QianfanEmbeddingsEndpoint

embeddings = QianfanEmbeddingsEndpoint(model="Embedding-V1")

# %% [markdown]
# ## 3.2 向量库
# 文档片段转换成向量之后，需要存储到向量库中。这样在用户提出问题时，可以将问题文本经过向量模型提取问题向量，再用该问题向量检索向量库中最相似的文本片段。
#
# 这里我们使用facebook开源的一个向量库faiss。

# %%
from langchain_community.vectorstores import FAISS

vector = FAISS.from_documents(documents, embeddings)

# %% [markdown]
# ## 4 准备RAG的调用流程：拼接问题和检索片段
# 在用户问题检索到相似的文档片段时，我们需要考虑如何将这些文档片段和用户问题拼接在一起，输入给大模型。
#
# 这里用到了刚才提到的PromptTemplate，并构造了一个新的调用链 doucument_chain，来完成这个工作。

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain

prompt_template = ChatPromptTemplate.from_template("""基于提供的【相关材料】回答最后的问题:
## 【相关材料】
{context}

## 最后的问题
问题: {input}""")

document_chain = create_stuff_documents_chain(llm, prompt_template)

# %% [markdown]
# 我们可以人工构造检索到的文档片段，然后用上面的doucument_chain进行大模型调用。这样来模拟检索的过程，测试我们的prompt模版。

# %%
from langchain_core.documents import Document

document_chain.invoke({
    "input": "招商银行在2019年获得了什么奖项?",
    "context": [Document(page_content='2021-12\tEDGE AWARDS 年度ESG实力先锋企业\t获奖\t[58]\n获奖时间\t奖项名称\t获奖结果\n2020\t2020胡润至尚优品\t获奖\n2019\t最佳股份制商业银行 [50]\t获奖\n2019\t最具投资价值银行 [50]\t获奖\n2019\t最佳手机银行 [50]\t获奖\n2014\t最具企业社会责任感公司奖\t获奖\n2014\t年度最佳财富管理银行\t获奖\n2014\t年度卓越私人银行服务\t获奖', metadata={'source': 'data/招商银行介绍.txt'})]
})
# Out:
# '根据提供的相关材料，招商银行在2019年获得了以下奖项：\n\n* 最佳股份制商业银行\n* 最具投资价值银行\n* 最佳手机银行\n\n这些奖项表明招商银行在当年在多个领域都取得了卓越的成就和认可。'

# %% [markdown]
# ## 5 串联向量检索和大模型调用
#
# 测试模版没问题后，我们来组装调用流程的最后一个环节：向量检索。
#
# 这里在上面doucument_chain的基础上创建了一个新的调用链 retrieval_chain，来将向量库检索的过程加入到调用流程中。

# %%
from langchain.chains import create_retrieval_chain

retriever = vector.as_retriever()
retrieval_chain = create_retrieval_chain(retriever, document_chain)

# %%
response = retrieval_chain.invoke({"input": "招商银行在2014年获得了什么奖项?"})
print(response["answer"])
# Out:
# 招商银行在2014年获得了以下两个奖项：
#
# 1. 最佳创新银行奖
# 2. 最佳中资银行奖
#
# 这两个奖项都是对招商银行在金融领域的卓越表现和创新的认可。

# %% [markdown]
# 这样就完成了整个的RAG准备，RAG调用的流程！

# %% [markdown]
# 另外，在reponse中可以查看context的字段，这就是问题在向量库中检索到的文档片段，这在调试RAG应用时很有用。

# %%
response
# Out:
# {'input': '招商银行在2014年获得了什么奖项?',
#  'context': [Document(page_content='1999\t招商银行官网中国十大优秀网站之一\t获奖\n1999\t亚洲最大100家银行第一位\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#   Document(page_content='。2016年8月，招商银行在"2016中国企业500强"中排名第39位。 [17]', metadata={'source': 'data/招商银行介绍.txt'}),
#   Document(page_content='2014\t最佳创新银行奖\t获奖\n2014\t最佳中资银行奖\t获奖\n2013\t深圳市金融创新奖\t获奖\n2013\t卓越手机银行奖\t获奖\n2013\t中国银行业星级服务机构\t获奖\n2013\t北亚最佳私人银行\t获奖\n2013\t年度广告主品牌奖\t获奖\n2012\t中国高端私人理财金鼎奖\t获奖\n2012\t年度十大品牌银行奖\t获奖\n2012\t品牌中国华谱奖\t获奖\n2012\t搜狐金融德胜奖年度企业\t获奖', metadata={'source': 'data/招商银行介绍.txt'}),
#   Document(page_content='招商银行（China Merchants Bank）1987年成立于深圳蛇口，资产总额110285.00亿元， [90]是中国境内第一家完全由企业法人持股的股份制商业银行，也是国家从体制外推动银行业改革的第一家试点银行。 [1-3] [74]', metadata={'source': 'data/招商银行介绍.txt'})],
#  'answer': '招商银行在2014年获得了以下两个奖项：\n\n1. 最佳创新银行奖\n2. 最佳中资银行奖\n\n这两个奖项都是对招商银行在金融领域的卓越表现和创新的认可。'}
